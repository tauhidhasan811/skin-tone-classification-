# %%
from deepface import DeepFace
import matplotlib.pyplot as plt
import cv2
# Out:
# WARNING:tensorflow:From c:\Users\Tahid Hasan\AppData\Local\Programs\Python\Python310\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# 25-10-18 08:19:22 - Directory C:\Users\Tahid Hasan\.deepface has been created
# 25-10-18 08:19:22 - Directory C:\Users\Tahid Hasan\.deepface\weights has been created

# %%
image_path = r"C:\Users\Tahid Hasan\Downloads\WhatsApp Image 2025-10-17 at 14.53.31_5113a3a2.jpg"

result = DeepFace.analyze(img_path=image_path, actions=['age', 'gender'], enforce_detection=False)
print("Analysis Result:\n", result)

img = cv2.imread(image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

if isinstance(result, list):
    gender = result[0]['dominant_gender']
    age = result[0]['age']
else:
    gender = result['dominant_gender']
    age = result['age']

plt.imshow(img)
plt.axis("off")
plt.title(f"Predicted: {gender}, Age: {age}")
plt.show()
# Out:
# Action: gender: 100%|██████████| 2/2 [00:00<00:00,  5.89it/s]
# Action: gender: 100%|██████████| 2/2 [00:00<00:00,  6.62it/s]
# Action: gender: 100%|██████████| 2/2 [00:00<00:00,  7.01it/s]
# Analysis Result:
#  [{'age': 22, 'region': {'x': 370, 'y': 520, 'w': 696, 'h': 696, 'left_eye': (825, 790), 'right_eye': (608, 802)}, 'face_confidence': 0.92, 'gender': {'Woman': np.float32(0.0009956406), 'Man': np.float32(99.999)}, 'dominant_gender': 'Man'}, {'age': 30, 'region': {'x': 165, 'y': 442, 'w': 60, 'h': 60, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0.96, 'gender': {'Woman': np.float32(1.1765529), 'Man': np.float32(98.823456)}, 'dominant_gender': 'Man'}, {'age': 25, 'region': {'x': 355, 'y': 1598, 'w': 94, 'h': 94, 'left_eye': None, 'right_eye': None}, 'face_confidence': 0.96, 'gender': {'Woman': np.float32(4.8294497), 'Man': np.float32(95.17055)}, 'dominant_gender': 'Man'}]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
